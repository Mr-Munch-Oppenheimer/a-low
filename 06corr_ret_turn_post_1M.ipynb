# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import joblib
from joblib import Parallel,delayed

# %%
trade_cal = pd.read_csv("trade_cal.csv")
trade_cal
# Out:
#      exchange  cal_date  is_open  pretrade_date
# 0         SSE  20141027        1       20141024
# 1         SSE  20141028        1       20141027
# 2         SSE  20141029        1       20141028
# 3         SSE  20141030        1       20141029
# 4         SSE  20141031        1       20141030
# ...       ...       ...      ...            ...
# 2427      SSE  20241021        1       20241018
# 2428      SSE  20241022        1       20241021
# 2429      SSE  20241023        1       20241022
# 2430      SSE  20241024        1       20241023
# 2431      SSE  20241025        1       20241024
#
# [2432 rows x 4 columns]

# %%
# stock_basic = pd.read_csv("stock_basic.csv")
# stock_basic

# %%
if not os.path.isdir("factor"):
    os.makedirs("factor")
    print("已创建factor文件夹")
else:
    print("factor文件夹已存在")
# Out:
# factor文件夹已存在

# %%
factor_name = "corr_ret_turn_post_1M"

# %%
path = "factor/" + factor_name

# %%
if not os.path.isdir(path):
    os.makedirs(path)
    print("已创建"+path+"文件夹")
else:
    print(path+"文件夹已存在")
# Out:
# factor/corr_ret_turn_post_1M文件夹已存在

# %%
# files = os.listdir("stock_daily")
# files

# %%
# df = pd.concat(
#     Parallel(n_jobs=4)(
#         delayed(pd.read_csv)(
#             os.path.join("stock_daily", file)
#         ) for file in files
#     ), ignore_index=True)

# %%
# A_trade_date = df.set_index(['trade_date','ts_code']).sort_index()
# A_trade_date

# %%
# df_index = pd.to_datetime(trade_cal.cal_date.tolist(), format='%Y%m%d')
# df_index = df_index.strftime('%Y-%m-%d')
# df_index

# %%
# A_trade_date.loc[df_index[0]]

# %%
# stock_daily_df=pd.read_csv("stock_daily/000001.SZ.csv")
# stock_daily_df["return"]=stock_daily_df['close'].pct_change(1)
# stock_daily_df

# %%
# daily_basic_df=pd.read_csv("daily_basic/000001.SZ.csv")
# daily_basic_df

# %%
# daily_basic_df.turnover_rate = daily_basic_df.turnover_rate.shift(1)
# daily_basic_df

# %%
# daily_basic_df["turnover_rate"].rolling(20).corr(stock_daily_df["return"])

# %%
@joblib.delayed
def task(index):
    ts_code = stock_basic.ts_code[index]
    stock_daily_df=pd.read_csv("stock_daily/"+ts_code+".csv")
    stock_daily_df["return"]=stock_daily_df['close'].pct_change(1)
    daily_basic_df=pd.read_csv("daily_basic/"+ts_code+".csv")
    daily_basic_df.turnover_rate = daily_basic_df.turnover_rate.shift(1)
    
    stock_daily_df["factor"]=daily_basic_df["turnover_rate"].rolling(20).corr(stock_daily_df["return"])
    
    stock_daily_df.to_csv(path+"/"+ts_code+".csv",index=0)
    return index
tasks=[]
for j in range(stock_basic.shape[0]):
#     print("stock_daily/"+stock_basic.ts_code[i]+".csv")
    tasks.append(task(j))
parallel = joblib.Parallel(n_jobs=5, verbose=10)
parallel(tasks)
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   3 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=5)]: Done   8 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=5)]: Done  15 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=5)]: Done  22 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=5)]: Batch computation too fast (0.1957s.) Setting batch_size=2.
# [Parallel(n_jobs=5)]: Done  31 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=5)]: Batch computation too fast (0.1770s.) Setting batch_size=4.
# [Parallel(n_jobs=5)]: Done  45 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=5)]: Done  79 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=5)]: Done 123 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=5)]: Done 175 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=5)]: Done 227 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=5)]: Done 287 tasks      | elapsed:    5.1s
# ...
